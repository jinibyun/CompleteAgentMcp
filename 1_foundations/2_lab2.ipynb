# %% [markdown]
# ## 다양한 LLM 모델 사용과 비교
#
# 이 예제에서는 GPT, GEMINI, CLAUDE 모델과 Ollama 모델을 사용한다. Groq 과 Deepseek 은 여기에서는 생략했다.
#
# ### 준비 사항
# - OpenAI API
# - GOOGLE_API_KEY
# - ANTHROPIC_API_KEY
#
# 각각의 api 키가 있어야 하고 이를 .evn file 에 기록한다. 주의할 점은 각 api 의 billing section 에서 5-10 달러의 최소 pay가 되어 있어야 한다.
#
# ### ollama LLM 설치
# 아래의 과정에 설명되어 있다.
#
# ### 요약
# 1. first let LLM (any) to create a question
# 2. secong let each LLM to answer to that question
# 3. looping and organize each llm and response
# 4. lastly let LLM (any) to rank that responses from LLM

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

# if deepseek_api_key:
#     print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
# else:
#     print("DeepSeek API Key not set (and this is optional)")

# if groq_api_key:
#     print(f"Groq API Key exists and begins {groq_api_key[:4]}")
# else:
#     print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are the senior climate-and-economic policy advisor to the president of the fictional mid-sized democratic country of Arboria (population 40 million; current primary energy mix: 45% coal/oil, 25% natural gas, 20% nuclear, 10% renewables; unemployment 6%; Gini 0.38). The president asks you to deliver a 15-year national plan that simultaneously (A) reduces greenhouse gas emissions by 75% relative to 2025 levels within 15 years; (B) sustains average GDP growth of at least 2.5% per year over the period; (C) reduces after-tax income inequality by at least 0.03 Gini points; (D) avoids any policy that would violate a constitutional ban on direct subsidies to fossil-fuel company profits or unconditional cash handouts to fossil workers; (E) does not rely on technologies that are not commercially available at scale today (no reliance on speculative large-scale DAC, fusion, or unproven synthetic fuels); and (F) ensures that average energy expenditures of the poorest 30% of households do not 
# ...

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-4.1-mini" #"gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Executive Summary**
# Given Arboria’s current energy mix and stringent criteria, fully meeting all six objectives simultaneously is **highly challenging but conditionally feasible** with some targeted relaxations, notably on energy cost caps for low-income households (criterion F) or slight GDP growth moderation (B). The key tension lies in rapid emissions cuts (75% in 15 years) without fossil subsidies, keeping energy costs nearly flat for the poor, and preserving robust growth. Scaling-up existing clean tech and smart fiscal/redistribution policies can approach these goals.
#
# ---
#
# ### (1) Feasibility Assessment
#
# - **Mutually incompatible constraints:**
# ...

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# # ARBORIA NATIONAL CLIMATE-ECONOMIC TRANSITION PLAN (2025-2040)
#
# ## 1. FEASIBILITY ASSESSMENT
#
# **Verdict: Achievable with tight margins and coordinated execution.**
#
# All objectives can theoretically be met simultaneously, but constraint (F) creates significant tension with (A) in years 1-5. The 75% emissions reduction is aggressive but feasible given 70% fossil dependence and commercially available renewables, nuclear, and efficiency technologies. Meeting 2.5% GDP growth while decarbonizing rapidly requires mobilizing ~$80-120 billion in green investment (~5-7.5% GDP assuming $40,000 per capita GDP). The inequality reduction is attainable through progressive carbon pricing revenue recycling.
#
# **Critical constraint:** Protecting poorest 30% from >5% energy cost increases while phasing out 70% of fossil energy in 5 years requires immediate, substantial revenue recycling—approximately 40-50% of carbon revenues must flow to low-income rebates.
#
# ...

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **1. Feasibility Assessment**
#
# Meeting all objectives (A-F) simultaneously within 15 years is exceptionally ambitious and presents significant tension, particularly the combination of a 75% emissions reduction (A) from a high-fossil base, strict financial constraints on fossil transitions (D), and protecting the poorest households (F) while sustaining high GDP growth (B). The rapid pace of decarbonization required implies major economic restructuring. However, with aggressive, well-designed policies, substantial public and private investment, and strong political will, it is *potentially feasible*. No specific constraint is mutually incompatible with *all* others, but achieving all simultaneously will require precise policy calibration and robust implementation.
#
# **2. Top Five Policy Measures (Ranked by Expected Net Social Benefit)**
#
# ...

# %%
# deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
# model_name = "deepseek-chat"

# response = deepseek.chat.completions.create(model=model_name, messages=messages)
# answer = response.choices[0].message.content

# display(Markdown(answer))
# competitors.append(model_name)
# answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

# groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
# model_name = "openai/gpt-oss-120b"

# response = groq.chat.completions.create(model=model_name, messages=messages)
# answer = response.choices[0].message.content

# display(Markdown(answer))
# competitors.append(model_name)
# answers.append(answer)

# %% [markdown]
# ## Ollama
#
# Ollama는 OpenAI 호환 엔드포인트를 제공하는 로컬 웹 서비스를 실행하며, 고성능 C++ 코드를 사용해 모델을 로컬에서 구동합니다.
#
# Ollama가 없다면 https://ollama.com 에서 Download 버튼을 눌러 설치하세요.
#
# 설치 후 http://localhost:11434 에 접속했을 때 "Ollama is running" 메시지가 보여야 합니다.
#
# Cursor를 재시작(경우에 따라 컴퓨터 재부팅)이 필요할 수 있습니다. 그런 다음 터미널(Ctrl+`)을 열고 ollama serve를 실행하세요.
#
# 유용한 Ollama 명령어 (터미널에서 실행하거나, 노트북에서 앞에 !를 붙여 실행):
#
# ollama pull <모델명> — 모델을 로컬에 다운로드
# ollama ls — 다운로드된 모델 목록 확인
# ollama rm <모델명> — 지정한 모델을 삭제
#
# ### 주의
# llama3.3 모델은 가정용 컴퓨터에 사용하기에는 너무 크며, 개인 컴퓨팅용으로 설계된 모델이 아닙니다 — 모든 리소스를 소진시킬 수 있습니다! 적당한 크기인 llama3.2 또는 llama3.2:1b를 사용하세요. 더 큰 모델을 원한다면 llama3.1이나 Qwen, Gemma, Phi, DeepSeek의 소형 변형 모델을 시도해보세요. 전체 모델 목록과 크기는 Ollama 모델 페이지를 참고하세요.

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11435/v1', api_key='ollama')
model_name = "gemma3:270m" #"llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Okay, I'm ready to develop a comprehensive and justified decision on this public policy. I will first analyze the pros and cons of the proposed on-demand shuttle fleet, considering safety, equity, economics, and public trust. I will then provide a detailed, phased implementation plan, a technical and non-technical intervention strategy, financial projections, an economic and social responsibility plan, and a measurement and mitigation strategy. Finally, I will assess the assumptions underlying my decision and provide a one-sentence summary of my overall confidence. Please provide the information you need for this analysis.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-4.1-mini', 'claude-sonnet-4-5', 'gemini-2.5-flash', 'gemma3:270m']
# ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-4.1-mini
#
# Certainly. Below is a comprehensive policy decision and operational plan addressing all points (A) through (H).
#
# ---
#
# ## (A) Deployment Decision & Justification
#
# **Choice**: **Phased deployment** over 3 years with continuous evaluation.
#
# **Justification**:
# A phased deployment balances potential transformative benefits (significant commute and emission reductions) against critical safety and social risks (0.06% serious incident chance, job displacement, energy price impacts). Immediate full deployment would risk public safety and trust without real-world verification, while outright delay/termination would forgo large societal gains evident in simulations. Phased rollout allows real-world validation, iterative safety improvements, and equitable mitigation.
#
# ---
#
# ## (B) Detailed Phased Implementation Plan
#
# ...

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Certainly. Below is a comprehensive policy decision and operational plan addressing all points (A) through (H).
#
# ---
#
# ## (A) Deployment Decision & Justification
#
# **Choice**: **Phased deployment** over 3 years with continuous evaluation.
#
# **Justification**:
# A phased deployment balances potential transformative benefits (significant commute and emission reductions) against critical safety and social risks (0.06% serious incident chance, job displacement, energy price impacts). Immediate full deployment would risk public safety and trust without real-world verification, while outright delay/termination would forgo large societal gains evident in simulations. Phased rollout allows real-world validation, iterative safety improvements, and equitable mitigation.
#
# ---
#
# ## (B) Detailed Phased Implementation Plan
#
# ...

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 4 competitors.
# Each model has been given this question:
#
# ...

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["3", "1", "2", "4"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemini-2.5-flash
# Rank 2: gpt-4.1-mini
# Rank 3: claude-sonnet-4-5
# Rank 4: gemma3:270m
